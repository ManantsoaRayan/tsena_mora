# %%
import pandas as pd

df = pd.read_csv("./products.csv")

df.head()
# Out:
#    Unnamed: 0                                            name  description  \
# 0           0  10 Chemises cartonnées couleurs vives 24x32 cm          NaN
# 1           1                10 tubes de gouache avec pinceau          NaN
# 2           2                      100 Pochettes perforées A4          NaN
# 3           3                      12 Crayons de couleur 18cm          NaN
# 4           4                12 Crayons de couleur effaçables          NaN
#
#                                                  ref  \
# 0  https://www.kibo.mg/tananarive/classement-et-a...
# 1  https://www.kibo.mg/tananarive/fournitures-sco...
# 2  https://www.kibo.mg/tananarive/classement-et-a...
# 3  https://www.kibo.mg/tananarive/fournitures-sco...
# 4  https://www.kibo.mg/tananarive/fournitures-sco...
#
#                                                image    price provider  \
# 0  https://www.kibo.mg/tananarive/42767-home_defa...  12900.0     Kibo
# ...

# %%
df.describe(include="all")
# Out:
#          Unnamed: 0                        name  description  \
# count   2081.000000                        2081          0.0
# unique          NaN                         839          NaN
# top             NaN  Fer à sec 2kg 1200W HI-600          NaN
# freq            NaN                         102          NaN
# mean    1040.000000                         NaN          NaN
# std      600.877275                         NaN          NaN
# min        0.000000                         NaN          NaN
# 25%      520.000000                         NaN          NaN
# 50%     1040.000000                         NaN          NaN
# 75%     1560.000000                         NaN          NaN
# max     2080.000000                         NaN          NaN
#
#                                                       ref  \
# count                                                2081
# unique                                                855
# ...
